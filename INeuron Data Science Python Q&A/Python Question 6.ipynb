# %% [markdown]
# Question no.6 :- Using the data from Question 3, write code to analyze the data and answer the following questions Note 1.
# Draw plots to demonstrate the analysis for the following questions for better visualizations.
#
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
#
# ● Get all Pokemons whose spawn rate is less than 5%
#
# ● Get all Pokemons that have less than 4 weaknesses
#
# ● Get all Pokemons that have no multipliers at all
#
# ● Get all Pokemons that do not have more than 2 evolutions
#
# ● Get all Pokemons whose spawn time is less than 300 seconds.
#
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
#
# ● Get all Pokemon who have more than two types of capabilities

# %% [markdown]
# Answer no.6

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel('/content/sample_data/pokemon_cleaned.xlsx')

# %%
dataset.head()
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             type  height  weight             candy  candy_count  egg  \
# 0  Grass, Poison    0.71     6.9   Bulbasaur Candy         25.0    2
# 1  Grass, Poison    0.99    13.0   Bulbasaur Candy        100.0    0
# 2  Grass, Poison    2.01   100.0   Bulbasaur Candy          NaN    0
# 3           Fire    0.61     8.5  Charmander Candy         25.0    2
# 4           Fire    1.09    19.0  Charmander Candy        100.0    0
#
#    spawn_chance  avg_spawns multipliers                    weakness  \
# 0         0.690        69.0      [1.58]  Fire, Ice, Flying, Psychic
# 1         0.042         4.2  [1.2, 1.6]  Fire, Ice, Flying, Psychic
# 2         0.017         1.7         NaN  Fire, Ice, Flying, Psychic
# 3         0.253        25.3      [1.65]         Water, Ground, Rock
# 4         0.012         1.2      [1.79]         Water, Ground, Rock
#
#                 next_evolution            prev_evolution  \
# 0      ['Ivysaur', 'Venusaur']                        []
# 1                 ['Venusaur']             ['Bulbasaur']
# 2                           []  ['Bulbasaur', 'Ivysaur']
# 3  ['Charmeleon', 'Charizard']                        []
# 4                ['Charizard']            ['Charmander']
#
#    spawn_time_total_secs
# 0                 1200.0
# 1                  420.0
# 2                  690.0
# 3                  525.0
# 4                 1140.0

# %%
dataset[dataset["spawn_chance"] < 0.05]
# Out:
#       id  num        name                                               img  \
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                type  height  weight             candy  candy_count  egg  \
# 1     Grass, Poison    0.99    13.0   Bulbasaur Candy        100.0    0
# 2     Grass, Poison    2.01   100.0   Bulbasaur Candy          NaN    0
# 4              Fire    1.09    19.0  Charmander Candy        100.0    0
# 5      Fire, Flying    1.70    90.5  Charmander Candy          NaN    0
# 7             Water    0.99    22.5    Squirtle Candy        100.0    0
# ..              ...     ...     ...               ...          ...  ...
# 145    Fire, Flying    2.01    60.0              None          NaN    0
# 147          Dragon    3.99    16.5     Dratini Candy        100.0    0
# 148  Dragon, Flying    2.21   210.0     Dratini Candy          NaN    0
# 149         Psychic    2.01   122.0              None          NaN    0
# 150         Psychic    0.41     4.0              None          NaN    0
#
#      spawn_chance  avg_spawns multipliers                    weakness  \
# 1          0.0420        4.20  [1.2, 1.6]  Fire, Ice, Flying, Psychic
# 2          0.0170        1.70         NaN  Fire, Ice, Flying, Psychic
# 4          0.0120        1.20      [1.79]         Water, Ground, Rock
# 5          0.0031        0.31         NaN       Water, Electric, Rock
# 7          0.0340        3.40       [1.4]             Electric, Grass
# ..            ...         ...         ...                         ...
# 145        0.0000        0.00         NaN       Water, Electric, Rock
# 147        0.0200        2.00      [2.05]          Ice, Dragon, Fairy
# 148        0.0011        0.11         NaN    Ice, Rock, Dragon, Fairy
# 149        0.0000        0.00         NaN            Bug, Ghost, Dark
# 150        0.0000        0.00         NaN            Bug, Ghost, Dark
#
#     next_evolution                prev_evolution  spawn_time_total_secs
# 1     ['Venusaur']                 ['Bulbasaur']                  420.0
# 2               []      ['Bulbasaur', 'Ivysaur']                  690.0
# 4    ['Charizard']                ['Charmander']                 1140.0
# 5               []  ['Charmander', 'Charmeleon']                  814.0
# 7    ['Blastoise']                  ['Squirtle']                  422.0
# ..             ...                           ...                    ...
# 145             []                            []                    NaN
# 147  ['Dragonite']                   ['Dratini']                  717.0
# 148             []      ['Dratini', 'Dragonair']                 1418.0
# 149             []                            []                    NaN
# 150             []                            []                    NaN
#
# [65 rows x 17 columns]

# %%
spawn_rate = dataset[dataset["spawn_chance"] < 5]

# %%
# Bar plot for all Pokemons whose spawn rate is less than 5%

plt.figure(figsize=(20,5))
sns.barplot(x = "name", y = "spawn_chance", data = spawn_rate)
plt.title("Pokemons with Spawn Rate Less Than 5%.")
plt.xlabel("Pokemon")
plt.ylabel("Spawn Rate (%)")
plt.xticks(rotation=90)
plt.show()

# %%
dataset["weakness"] = dataset["weakness"].apply(lambda x: x.split(", "))

# %%
weaknesses = dataset[dataset["weakness"].apply(len) < 4]

# %%
weaknesses
# Out:
#       id  num        name                                               img  \
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6      7    7    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#              type  height  weight             candy  candy_count  egg  \
# 3            Fire    0.61     8.5  Charmander Candy         25.0    2
# 4            Fire    1.09    19.0  Charmander Candy        100.0    0
# 5    Fire, Flying    1.70    90.5  Charmander Candy          NaN    0
# 6           Water    0.51     9.0    Squirtle Candy         25.0    2
# 7           Water    0.99    22.5    Squirtle Candy        100.0    0
# ..            ...     ...     ...               ...          ...  ...
# 145  Fire, Flying    2.01    60.0              None          NaN    0
# 146        Dragon    1.80     3.3     Dratini Candy         25.0   10
# 147        Dragon    3.99    16.5     Dratini Candy        100.0    0
# 149       Psychic    2.01   122.0              None          NaN    0
# 150       Psychic    0.41     4.0              None          NaN    0
#
#      spawn_chance  avg_spawns   multipliers                 weakness  \
# 3          0.2530       25.30        [1.65]    [Water, Ground, Rock]
# 4          0.0120        1.20        [1.79]    [Water, Ground, Rock]
# 5          0.0031        0.31           NaN  [Water, Electric, Rock]
# 6          0.5800       58.00         [2.1]        [Electric, Grass]
# 7          0.0340        3.40         [1.4]        [Electric, Grass]
# ..            ...         ...           ...                      ...
# 145        0.0000        0.00           NaN  [Water, Electric, Rock]
# 146        0.3000       30.00  [1.83, 1.84]     [Ice, Dragon, Fairy]
# 147        0.0200        2.00        [2.05]     [Ice, Dragon, Fairy]
# 149        0.0000        0.00           NaN       [Bug, Ghost, Dark]
# 150        0.0000        0.00           NaN       [Bug, Ghost, Dark]
#
#                   next_evolution                prev_evolution  \
# 3    ['Charmeleon', 'Charizard']                            []
# 4                  ['Charizard']                ['Charmander']
# 5                             []  ['Charmander', 'Charmeleon']
# 6     ['Wartortle', 'Blastoise']                            []
# 7                  ['Blastoise']                  ['Squirtle']
# ..                           ...                           ...
# 145                           []                            []
# 146   ['Dragonair', 'Dragonite']                            []
# 147                ['Dragonite']                   ['Dratini']
# 149                           []                            []
# 150                           []                            []
#
#      spawn_time_total_secs
# 3                    525.0
# 4                   1140.0
# 5                    814.0
# 6                    265.0
# 7                    422.0
# ..                     ...
# 145                    NaN
# 146                  401.0
# 147                  717.0
# 149                    NaN
# 150                    NaN
#
# [102 rows x 17 columns]

# %%
# Bar plot for Pokemons that have less than 4 weaknesses

plt.figure(figsize=(10, 5))
sns.countplot(x=weaknesses["weakness"].apply(len))
plt.title("Pokemons with Less Than 4 Weaknesses")
plt.xlabel("Number of Weaknesses")
plt.ylabel("Count of Pokémon")
plt.show()

# %%
dataset.head()
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             type  height  weight             candy  candy_count  egg  \
# 0  Grass, Poison    0.71     6.9   Bulbasaur Candy         25.0    2
# 1  Grass, Poison    0.99    13.0   Bulbasaur Candy        100.0    0
# 2  Grass, Poison    2.01   100.0   Bulbasaur Candy          NaN    0
# 3           Fire    0.61     8.5  Charmander Candy         25.0    2
# 4           Fire    1.09    19.0  Charmander Candy        100.0    0
#
#    spawn_chance  avg_spawns multipliers                      weakness  \
# 0         0.690        69.0      [1.58]  [Fire, Ice, Flying, Psychic]
# 1         0.042         4.2  [1.2, 1.6]  [Fire, Ice, Flying, Psychic]
# 2         0.017         1.7         NaN  [Fire, Ice, Flying, Psychic]
# 3         0.253        25.3      [1.65]         [Water, Ground, Rock]
# 4         0.012         1.2      [1.79]         [Water, Ground, Rock]
#
#                 next_evolution            prev_evolution  \
# 0      ['Ivysaur', 'Venusaur']                        []
# 1                 ['Venusaur']             ['Bulbasaur']
# 2                           []  ['Bulbasaur', 'Ivysaur']
# 3  ['Charmeleon', 'Charizard']                        []
# 4                ['Charizard']            ['Charmander']
#
#    spawn_time_total_secs
# 0                 1200.0
# 1                  420.0
# 2                  690.0
# 3                  525.0
# 4                 1140.0

# %%
unique_multipliers = dataset["multipliers"].unique()    # Checking unique values in multipliers column
print(unique_multipliers)
# Out:
# ['[1.58]' '[1.2, 1.6]' nan '[1.65]' '[1.79]' '[2.1]' '[1.4]' '[1.05]'
#  '[3.55, 3.79]' '[1.01, 1.09]' '[3.01, 3.41]' '[1.71, 1.92]'
#  '[2.55, 2.73]' '[2.66, 2.68]' '[2.21, 2.27]' '[2.34]' '[2.45]'
#  '[1.63, 2.48]' '[1.83, 2.48]' '[1.64, 1.7]' '[1.83]' '[2.03, 2.14]'
#  '[2.74, 2.81]' '[1.85]' '[2.6, 3.67]' '[1.5]' '[1.49]' '[2.02]'
#  '[1.86, 1.9]' '[2.69]' '[1.98]' '[2.27]' '[2.17, 2.28]' '[2.31, 2.36]'
#  '[1.72, 1.73]' '[1.95]' '[1.36, 1.95]' '[1.64, 1.65]' '[1.7]' '[1.57]'
#  '[1.59]' '[2.52]' '[1.75, 1.76]' '[1.64, 1.72]' '[1.48, 1.5]' '[2.21]'
#  '[2.16, 2.17]' '[2.19, 2.24]' '[1.04, 1.96]' '[2.44]' '[2.65]' '[1.78]'
#  '[1.56, 1.8]' '[2.08, 2.09]' '[2.36, 2.4]' '[2.01, 2.02]' '[2.7, 3.18]'
#  '[1.67]' '[1.11]' '[1.91]' '[2.23]' '[2.15, 2.2]' '[2.38, 2.41]'
#  '[10.1, 11.8]' '[2.02, 2.64]' '[2.12]' '[1.97, 2.37]' '[1.83, 1.84]'
#  '[2.05]']

# %%
# Creating new variable as 'no_multipliers' which will store values of all Pokemons that have no multipliers at all.

no_multipliers = dataset[dataset["multipliers"].apply(lambda x: isinstance(x, float) or len(x) == 0)]

# %%
no_multipliers
# Out:
#       id  num        name                                               img  \
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 8      9    9   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 11    12   12  Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# 14    15   15    Beedrill  http://www.serebii.net/pokemongo/pokemon/015.png
# ..   ...  ...         ...                                               ...
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                  type  height  weight             candy  candy_count  egg  \
# 2       Grass, Poison    2.01   100.0   Bulbasaur Candy          NaN    0
# 5        Fire, Flying    1.70    90.5  Charmander Candy          NaN    0
# 8               Water    1.60    85.5    Squirtle Candy          NaN    0
# 11        Bug, Flying    1.09    32.0    Caterpie Candy          NaN    0
# 14        Bug, Poison    0.99    29.5      Weedle Candy          NaN    0
# ..                ...     ...     ...               ...          ...  ...
# 144  Electric, Flying    1.60    52.6              None          NaN    0
# 145      Fire, Flying    2.01    60.0              None          NaN    0
# 148    Dragon, Flying    2.21   210.0     Dratini Candy          NaN    0
# 149           Psychic    2.01   122.0              None          NaN    0
# 150           Psychic    0.41     4.0              None          NaN    0
#
#      spawn_chance  avg_spawns multipliers  \
# 2          0.0170        1.70         NaN
# 5          0.0031        0.31         NaN
# 8          0.0067        0.67         NaN
# 11         0.0220        2.20         NaN
# 14         0.0510        5.10         NaN
# ..            ...         ...         ...
# 144        0.0000        0.00         NaN
# 145        0.0000        0.00         NaN
# 148        0.0011        0.11         NaN
# 149        0.0000        0.00         NaN
# 150        0.0000        0.00         NaN
#
#                                 weakness next_evolution  \
# 2           [Fire, Ice, Flying, Psychic]             []
# 5                [Water, Electric, Rock]             []
# 8                      [Electric, Grass]             []
# 11   [Fire, Electric, Ice, Flying, Rock]             []
# 14         [Fire, Flying, Psychic, Rock]             []
# ..                                   ...            ...
# 144                          [Ice, Rock]             []
# 145              [Water, Electric, Rock]             []
# 148           [Ice, Rock, Dragon, Fairy]             []
# 149                   [Bug, Ghost, Dark]             []
# 150                   [Bug, Ghost, Dark]             []
#
#                    prev_evolution  spawn_time_total_secs
# 2        ['Bulbasaur', 'Ivysaur']                  690.0
# 5    ['Charmander', 'Charmeleon']                  814.0
# 8       ['Squirtle', 'Wartortle']                    6.0
# 11        ['Caterpie', 'Metapod']                  323.0
# 14           ['Weedle', 'Kakuna']                  290.0
# ..                            ...                    ...
# 144                            []                    NaN
# 145                            []                    NaN
# 148      ['Dratini', 'Dragonair']                 1418.0
# 149                            []                    NaN
# 150                            []                    NaN
#
# [81 rows x 17 columns]

# %%
# Creating new variable as 'no_more_than_2_evolutions' which will store values of all Pokemons that do not have more than 2 evolutions.

no_more_than_2_evolutions = dataset[dataset["next_evolution"].apply(lambda x: len(x) if isinstance(x, list) else 0) <= 2]

# %%
no_more_than_2_evolutions
# Out:
#       id  num        name                                               img  \
# 0      1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...         ...                                               ...
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                type  height  weight             candy  candy_count  egg  \
# 0     Grass, Poison    0.71     6.9   Bulbasaur Candy         25.0    2
# 1     Grass, Poison    0.99    13.0   Bulbasaur Candy        100.0    0
# 2     Grass, Poison    2.01   100.0   Bulbasaur Candy          NaN    0
# 3              Fire    0.61     8.5  Charmander Candy         25.0    2
# 4              Fire    1.09    19.0  Charmander Candy        100.0    0
# ..              ...     ...     ...               ...          ...  ...
# 146          Dragon    1.80     3.3     Dratini Candy         25.0   10
# 147          Dragon    3.99    16.5     Dratini Candy        100.0    0
# 148  Dragon, Flying    2.21   210.0     Dratini Candy          NaN    0
# 149         Psychic    2.01   122.0              None          NaN    0
# 150         Psychic    0.41     4.0              None          NaN    0
#
#      spawn_chance  avg_spawns   multipliers                      weakness  \
# 0          0.6900       69.00        [1.58]  [Fire, Ice, Flying, Psychic]
# 1          0.0420        4.20    [1.2, 1.6]  [Fire, Ice, Flying, Psychic]
# 2          0.0170        1.70           NaN  [Fire, Ice, Flying, Psychic]
# 3          0.2530       25.30        [1.65]         [Water, Ground, Rock]
# 4          0.0120        1.20        [1.79]         [Water, Ground, Rock]
# ..            ...         ...           ...                           ...
# 146        0.3000       30.00  [1.83, 1.84]          [Ice, Dragon, Fairy]
# 147        0.0200        2.00        [2.05]          [Ice, Dragon, Fairy]
# 148        0.0011        0.11           NaN    [Ice, Rock, Dragon, Fairy]
# 149        0.0000        0.00           NaN            [Bug, Ghost, Dark]
# 150        0.0000        0.00           NaN            [Bug, Ghost, Dark]
#
#                   next_evolution            prev_evolution  \
# 0        ['Ivysaur', 'Venusaur']                        []
# 1                   ['Venusaur']             ['Bulbasaur']
# 2                             []  ['Bulbasaur', 'Ivysaur']
# 3    ['Charmeleon', 'Charizard']                        []
# 4                  ['Charizard']            ['Charmander']
# ..                           ...                       ...
# 146   ['Dragonair', 'Dragonite']                        []
# 147                ['Dragonite']               ['Dratini']
# 148                           []  ['Dratini', 'Dragonair']
# 149                           []                        []
# 150                           []                        []
#
#      spawn_time_total_secs
# 0                   1200.0
# 1                    420.0
# 2                    690.0
# 3                    525.0
# 4                   1140.0
# ..                     ...
# 146                  401.0
# 147                  717.0
# 148                 1418.0
# 149                    NaN
# 150                    NaN
#
# [151 rows x 17 columns]

# %%
# Bar plot for Pokemons that do not have more than 2 evolutions

plt.figure(figsize=(20, 5))
sns.countplot(x="next_evolution", data=no_more_than_2_evolutions)
plt.title("Pokemons with Not More Than 2 Evolutions")
plt.xlabel("Evolutions")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.yticks(range(0, 85, 5))
plt.show()

# %%
# Creating new variable as 'spawn_time_less_than_300' which will store values of all Pokemons whose spawn time is less than 300 seconds.

spawn_time_less_than_300 = dataset[dataset["spawn_time_total_secs"] < 300]

# %%
spawn_time_less_than_300
# Out:
#       id  num       name                                               img  \
# 6      7    7   Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 8      9    9  Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 10    11   11    Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 12    13   13     Weedle  http://www.serebii.net/pokemongo/pokemon/013.png
# 13    14   14     Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# ..   ...  ...        ...                                               ...
# 127  128  128     Tauros  http://www.serebii.net/pokemongo/pokemon/128.png
# 129  130  130   Gyarados  http://www.serebii.net/pokemongo/pokemon/130.png
# 134  135  135    Jolteon  http://www.serebii.net/pokemongo/pokemon/135.png
# 136  137  137    Porygon  http://www.serebii.net/pokemongo/pokemon/137.png
# 139  140  140     Kabuto  http://www.serebii.net/pokemongo/pokemon/140.png
#
#               type  height  weight           candy  candy_count  egg  \
# 6            Water    0.51     9.0  Squirtle Candy         25.0    2
# 8            Water    1.60    85.5  Squirtle Candy          NaN    0
# 10             Bug    0.71     9.9  Caterpie Candy         50.0    0
# 12     Bug, Poison    0.30     3.2    Weedle Candy         12.0    2
# 13     Bug, Poison    0.61    10.0    Weedle Candy         50.0    0
# ..             ...     ...     ...             ...          ...  ...
# 127         Normal    1.40    88.4            None          NaN    5
# 129  Water, Flying    6.50   235.0  Magikarp Candy          NaN    0
# 134       Electric    0.79    24.5            None          NaN    0
# 136         Normal    0.79    36.5            None          NaN    5
# 139    Rock, Water    0.51    11.5    Kabuto Candy         50.0   10
#
#      spawn_chance  avg_spawns   multipliers  \
# 6          0.5800       58.00         [2.1]
# 8          0.0067        0.67           NaN
# 10         0.1870       18.70  [3.55, 3.79]
# 12         7.1200      712.00  [1.01, 1.09]
# 13         0.4400       44.00  [3.01, 3.41]
# ..            ...         ...           ...
# 127        0.1200       12.00           NaN
# 129        0.0032        0.32           NaN
# 134        0.0120        1.20           NaN
# 136        0.0120        1.20           NaN
# 139        0.1000       10.00  [1.97, 2.37]
#
#                                 weakness              next_evolution  \
# 6                      [Electric, Grass]  ['Wartortle', 'Blastoise']
# 8                      [Electric, Grass]                          []
# 10                  [Fire, Flying, Rock]              ['Butterfree']
# 12         [Fire, Flying, Psychic, Rock]      ['Kakuna', 'Beedrill']
# 13         [Fire, Flying, Psychic, Rock]                ['Beedrill']
# ..                                   ...                         ...
# 127                           [Fighting]                          []
# 129                     [Electric, Rock]                          []
# 134                             [Ground]                          []
# 136                           [Fighting]                          []
# 139  [Electric, Grass, Fighting, Ground]                ['Kabutops']
#
#                 prev_evolution  spawn_time_total_secs
# 6                           []                  265.0
# 8    ['Squirtle', 'Wartortle']                    6.0
# 10                ['Caterpie']                  131.0
# 12                          []                  141.0
# 13                  ['Weedle']                  150.0
# ..                         ...                    ...
# 127                         []                   37.0
# 129               ['Magikarp']                  135.0
# 134                  ['Eevee']                  150.0
# 136                         []                  169.0
# 139                         []                    5.0
#
# [75 rows x 17 columns]

# %%
# Creating new variable as 'more_than_two_types' which will store values of all Pokemons who have more than two types of capabilities.

more_than_two_types = dataset[dataset["type"].apply(lambda x: len(x.split(", "))) > 2]

# %%
more_than_two_types
# Out:
# Empty DataFrame
# Columns: [id, num, name, img, type, height, weight, candy, candy_count, egg, spawn_chance, avg_spawns, multipliers, weakness, next_evolution, prev_evolution, spawn_time_total_secs]
# Index: []
