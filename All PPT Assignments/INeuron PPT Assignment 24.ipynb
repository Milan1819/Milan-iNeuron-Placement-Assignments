# %% [markdown]
# Question no.1 :- **Roman to Integer**
#
# Roman numerals are represented by seven different symbols: `I`, `V`, `X`, `L`, `C`, `D` and `M`.
#
# ```
# SymbolValue
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# ```
#
# For example, `2` is written as `II` in Roman numeral, just two ones added together. `12` is written as `XII`, which is simply `X + II`. The number `27` is written as `XXVII`, which is `XX + V + II`.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not `IIII`. Instead, the number four is written as `IV`. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as `IX`. There are six instances where subtraction is used:
#
# - `I` can be placed before `V` (5) and `X` (10) to make 4 and 9.
# - `X` can be placed before `L` (50) and `C` (100) to make 40 and 90.
# - `C` can be placed before `D` (500) and `M` (1000) to make 400 and 900.
#
# Given a roman numeral, convert it to an integer.
#
# **Example 1:**
#
# ```
# Input: s = "III"
# Output: 3
# Explanation: III = 3.
# ```

# %% [markdown]
# Answer no.1

# %%
class R_to_I:
    def roman_to_Int(self,s):
        roman_to_integer = {
            'I': 1,
            'V': 5,
            'X': 10,
            'L': 50,
            'C': 100,
            'D': 500,
            'M': 1000
        }
        s = s.replace("IV", "IIII").replace("IX", "VIIII").replace("XL", "XXXX").replace("XC", "LXXXX").replace("CD", "CCCC").replace("CM", "DCCCC")
        return sum(map(lambda x: roman_to_integer[x], s))



obj = R_to_I()
s = "IX"
print(obj.roman_to_Int(s))
# Out:
# 9

# %% [markdown]
# Question no.2 :- **Longest Substring Without Repeating Characters**
#
# Given a string `s`, find the length of the **longest substring** without repeating characters.
#
# **Example 1:**
#
# ```
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3.
# ```

# %% [markdown]
# Answer no.2

# %%
class Length_of_Longest_Ss:
    def get_length(self,s):
        my_set = set()
        res = 0
        l = 0

        for r in range(len(s)):
            while s[r] in my_set:
                my_set.remove(s[l])
                l+=1
            my_set.add(s[r])
            res = max(res,r-l+1)
        return res



obj1 = Length_of_Longest_Ss()
s = "BlueBeetle"
print(obj1.get_length(s))
# Out:
# 4

# %% [markdown]
# Question no.3 :- **Majority Element**
#
# Given an array `nums` of size `n`, return *the majority element*.
#
# The majority element is the element that appears more than `⌊n / 2⌋` times. You may assume that the majority element always exists in the array.
#
# **Example 1:**
#
# ```
# Input: nums = [3,2,3]
# Output: 3
# ```

# %% [markdown]
# Answer no.3

# %%
class Majority_ele:
    def get_ele(self,nums):
        res = None
        count = 0

        for i in nums:
            if count == 0:
                res = i
            count += (1 if i == res else -1)
        return res



obj2 = Majority_ele()
nums = [3,2,3]
print(obj2.get_ele(nums))
# Out:
# 3

# %% [markdown]
# Question no.4 :- **Group Anagram**
#
# Given an array of strings `strs`, group **the anagrams** together. You can return the answer in **any order**.
#
# An **Anagram** is a word or phrase formed by rearranging the letters of a different word or phrase, typically using all the original letters exactly once.
#
# **Example 1:**
#
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]

# %% [markdown]
# Answer no.4

# %%
class Anagrams:
    def group_Anagrams(self,strs):
        d = {}

        for word in strs:
            new_Word = ''.join(sorted(word))
            if new_Word not in d:
                d[new_Word] = [word]
            else:
                d[new_Word].append(word)

        final = []

        for value in d.values():
            final.append(value)
        return final



obj3 = Anagrams()
strs = ["eat","tea","tan","ate","nat","bat"]
print(obj3.group_Anagrams(strs))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# Question no.5 :- **Ugly Numbers**
#
# An **ugly number** is a positive integer whose prime factors are limited to `2`, `3`, and `5`.
#
# Given an integer `n`, return *the* `nth` ***ugly number***.
#
# **Example 1:**
#
# ```
# Input: n = 10
# Output: 12
# Explanation: [1, 2, 3, 4, 5, 6, 8, 9, 10, 12] is the sequence of the first 10 ugly numbers.
# ```

# %% [markdown]
# Answer no.5

# %%
class Ugly_nums:
    def ugly_list(self,n):
        ans=[1]
        prod_2= 0
        prod_3= 0
        prod_5= 0

        for i in range(1,n):
            a=ans[prod_2]*2
            b=ans[prod_3]*3
            c=ans[prod_5]*5
            m=min(a,b,c)
            ans.append(m)

            if m==a:
                prod_2+=1
            if m==b:
                prod_3+=1
            if m==c:
                prod_5+=1
        return ans



obj4 = Ugly_nums()
n = 10
print(obj4.ugly_list(n))
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 10, 12]

# %% [markdown]
# Question no.6 :- **Top K Frequent Words**
#
# Given an array of strings `words` and an integer `k`, return *the* `k` *most frequent strings*.
#
# Return the answer **sorted** by **the frequency** from highest to lowest. Sort the words with the same frequency by their **lexicographical order**.
#
# **Example 1:**
#
# ```
# Input: words = ["i","love","leetcode","i","love","coding"], k = 2
# Output: ["i","love"]
# Explanation: "i" and "love" are the two most frequent words.
# Note that "i" comes before "love" due to a lower alphabetical order.
# ```

# %% [markdown]
# Answer no.6

# %%
from collections import Counter
class Top_Frequent:
    def top_k_frequent(self,words,k):
        words = sorted(words)
        counts = Counter(words)
        return [i for i, _ in counts.most_common(k)]



obj5 = Top_Frequent()
words = ["Batman","Superman","Joker","Batman","Flash","Joker","Batman","GreenLantern"]
k = 2
print(obj5.top_k_frequent(words,k))
# Out:
# ['Batman', 'Joker']

# %% [markdown]
# Question no.7 :- **Sliding Window Maximum**
#
# You are given an array of integers `nums`, there is a sliding window of size `k` which is moving from the very left of the array to the very right. You can only see the `k` numbers in the window. Each time the sliding window moves right by one position.
#
# Return *the max sliding window*.
#
# **Example 1:**
#
# ```
# Input: nums = [1,3,-1,-3,5,3,6,7], k = 3
# Output: [3,3,5,5,6,7]
# Explanation:
# Window position                Max
# ---------------               -----
# [1  3  -1] -3  5  3  6 7         3
#  1 [3  -1  -3] 5  3  6 7         3
#  1  3 [-1  -3  5] 3  6 7         5
#  1  3  -1 [-3  5  3] 6 7         5
#  1  3  -1  -3 [5  3  6]7         6
#  1  3  -1  -3  5 [3  6  7]       7
# ```

# %% [markdown]
# Answer no.7

# %%
from collections import deque
class max_sliding_window:
    def get_max(self,nums,k):

        q = deque()
        res = []

        for i, cur in enumerate(nums):
            while q and nums[q[-1]] <= cur:
                q.pop()
            q.append(i)

            if q[0] == i - k:
                q.popleft()

            if i >= k - 1:
                res.append(nums[q[0]])
        return res



obj6 = max_sliding_window()
nums = [1,3,-1,-3,5,3,6,7]
k = 3
print(obj6.get_max(nums,k))
# Out:
# [3, 3, 5, 5, 6, 7]

# %% [markdown]
# Question no.8 :- **Find K Closest Elements**
#
# Given a **sorted** integer array `arr`, two integers `k` and `x`, return the `k` closest integers to `x` in the array. The result should also be sorted in ascending order.
#
# An integer `a` is closer to `x` than an integer `b` if:
#
# - `|a - x| < |b - x|`, or
# - `|a - x| == |b - x|` and `a < b`
#
# **Example 1:**
#
# ```
# Input: arr = [1,2,3,4,5], k = 4, x = 3
# Output: [1,2,3,4]
# ```

# %% [markdown]
# Answer no.8

# %%
class closest_elements:
    def get_eles(self,arr,k,x):
        val=[]

        for i in arr:
            val.append([i,abs(x-i)])
        ans=[]

        for i in sorted(val,key=lambda x:x[1]):
            k-=1
            ans.append(i[0])
            if k==0: break
        return sorted(ans)



obj7 = closest_elements()
arr = [1,2,3,4,5]
k,x = 4,3
print(obj7.get_eles(arr,k,x))
# Out:
# [1, 2, 3, 4]
