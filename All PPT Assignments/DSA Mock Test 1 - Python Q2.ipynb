# %% [markdown]
# Question :- First Unique Character in a String
#
# Given a string s, find the first non-repeating character in it and return its index. If it does not exist, return -1.
#
# Example 1:
#
# Input: s = "leetcode"
#
# Output: 0
#
# Example 2:
#
# Input: s = "loveleetcode"
#
# Output: 2
#
# Example 3:
#
# Input: s = "aabb"
#
# Output: -1
#
# Constraints:
#
# a. 1 <= s.length <= 10^5
#
# b. s consists of only lowercase English letters.

# %% [markdown]
# Answer

# %%
from collections import Counter

class Unique_Char:
    def first_uniq_char(self,s):

        count = Counter(s)

        for i in range(len(s)):
            if count[s[i]] == 1:
                return i
        return -1


obj = Unique_Char() 
s = "restoresynderverse"
print(obj.first_uniq_char(s))
# Out:
# 3
