# %% [markdown]
# Question no.1 :- Given preorder of a binary tree, calculate its depth(or height)[starting from depth 0]. The preorder is given as a string with two possible characters.
#
# 1. ‘l’ denotes the leaf
#
# 2. ‘n’ denotes internal node
#
# The given tree can be seen as a full binary tree where every node has 0 or two children. The two children of a node can ‘n’ or ‘l’ or mix of both.
#
# **Examples :**
#
# Input  : nlnll
#
# Output : 2

# %% [markdown]
# Answer no.1

# %%
def find_depth_tool(tree,n,index) :

    if (index[0] >= n or tree[index[0]] == 'l'):
        return 0

    index[0] += 1
    left = find_depth_tool(tree,n,index)

    index[0] += 1
    right = find_depth_tool(tree,n,index)

    return (max(left, right) + 1)

def find_depth(tree, n) :

    index = [0]
    return find_depth_tool(tree,n,index)


tree= "nlnll"
n = len(tree)

print(find_depth(tree,n))
# Out:
# 2

# %% [markdown]
# Question no.2 :- Given a Binary tree, the task is to print the **left view** of the Binary Tree. The left view of a Binary Tree is a set of leftmost nodes for every level.
#
# **Examples:**
#
# ***Input:***
#
#             4
#
#           /   \
#
#         5     2
#
#              /   \
#
#             3     1
#
#            /  \
#
#           6    7
#
# ***Output:** 4 5 3 6*

# %% [markdown]
# Answer no.2

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def left_view_tool(root, level, max_level):

    if root is None:
        return

    if (max_level[0] < level):
        print (root.data, end = " ")
        max_level[0] = level

    left_view_tool(root.left, level + 1, max_level)
    left_view_tool(root.right, level + 1, max_level)

def left_View(root):
    max_level = [0]
    left_view_tool(root, 1, max_level)



root = Node(4)
root.left = Node(5)
root.right = Node(2)
root.right.right = Node(1)
root.right.left = Node(3)
root.right.left.left = Node(6)
root.right.left.right = Node(7)

left_View(root)
# Out:
# 4 5 3 6

# %% [markdown]
# Question no.3 :- Given a Binary Tree, print the Right view of it.
#
# The right view of a Binary Tree is a set of nodes visible when the tree is visited from the Right side.
#
# **Examples:**
#
# **Input:**
#
#          1
#
#       /     \
#
#    2         3
#
# /   \       /  \
#
# 4     5   6    7
#
#              \
#
#                8
#
# **Output**:
#
# Right view of the tree is 1 3 7 8
#
# **Input:**
#
#          1
#
#        /
#
#     8
#
#   /
#
# 7
#
# **Output**:
#
# Right view of the tree is 1 8 7

# %% [markdown]
# Answer no.3

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def right_view_tool(root, level, max_level):

    if root is None:
        return

    if (max_level[0] < level):
        print (root.data, end = " ")
        max_level[0] = level

    right_view_tool(root.right, level + 1, max_level)
    right_view_tool(root.left, level + 1, max_level)

def right_View(root):
    max_level = [0]
    right_view_tool(root, 1, max_level)



root = Node(4)
root.left = Node(5)
root.right = Node(2)
root.right.right = Node(1)
root.right.left = Node(3)
root.right.left.left = Node(6)
root.right.left.right = Node(7)

right_View(root)
# Out:
# 4 2 1 7

# %% [markdown]
# Question no.4 :- Given a Binary Tree, The task is to print the **bottom view** from left to right. A node **x** is there in output if x is the bottommost node at its horizontal distance. The horizontal distance of the left child of a node x is equal to a horizontal distance of x minus 1, and that of a right child is the horizontal distance of x plus 1.
#
# **Examples:**
#
# **Input:**
#
#              20
#
#            /     \
#
#         8         22
#
#     /      \         \
#
# 5         3        25
#
#         /    \
#
#    10       14
#
# **Output:** 5, 10, 3, 14, 25.
#
# **Input:**
#
#              20
#
#            /     \
#
#         8         22
#
#     /      \      /   \
#
#  5         3    4     25
#
#          /    \
#
#      10       14
#
# **Output:**
#
# 5 10 4 14 25.
#
# **Explanation:**
#
# If there are multiple bottom-most nodes for a horizontal distance from the root, then print the later one in the level traversal.
#
# **3 and 4** are both the bottom-most nodes at a horizontal distance of 0, we need to print 4.

# %% [markdown]
# Answer no.4

# %%
class Node:

    def __init__(self, key = None, left = None, right = None):

        self.data = key
        self.left = left
        self.right = right

def print_bottomView(root):

    d = dict()

    print_bottomView_tool(root, d, 0, 0)

    for i in sorted(d.keys()):
        print(d[i][0], end = " ")

def print_bottomView_tool(root, d, hd, level):

    if root is None:
        return

    if hd in d:
        if level >= d[hd][1]:
            d[hd] = [root.data, level]
    else:
        d[hd] = [root.data, level]

    print_bottomView_tool(root.left, d, hd - 1,level + 1)

    print_bottomView_tool(root.right, d, hd + 1,level + 1)



root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(5)
root.left.right = Node(3)
root.right.left = Node(4)
root.right.right = Node(25)
root.left.right.left = Node(10)
root.left.right.right = Node(14)

print_bottomView(root)
# Out:
# 5 10 4 14 25
